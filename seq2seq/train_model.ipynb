# %%
from ModelAndData import ModelDealer
# Out:
# Using TensorFlow backend.

# %%
M = ModelDealer( downcast = 500, base = 'dataset_mu10_')
# Out:
# Ready for model all_4L_20H_5C_DC500

# %%
M.make_model()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# phi_layers (InputLayer)          (None, 4, 20)         0
# ____________________________________________________________________________________________________
# split_0 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ____________________________________________________________________________________________________
# split_1 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ____________________________________________________________________________________________________
# split_2 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ____________________________________________________________________________________________________
# split_3 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ____________________________________________________________________________________________________
# sequence_layer_0 (Reshape)       (None, 20, 1)         0           split_0[0][0]
# ____________________________________________________________________________________________________
# sequence_layer_1 (Reshape)       (None, 20, 1)         0           split_1[0][0]
# ____________________________________________________________________________________________________
# sequence_layer_2 (Reshape)       (None, 20, 1)         0           split_2[0][0]
# ____________________________________________________________________________________________________
# sequence_layer_3 (Reshape)       (None, 20, 1)         0           split_3[0][0]
# ____________________________________________________________________________________________________
# masking_layer_0 (Masking)        (None, 20, 1)         0           sequence_layer_0[0][0]
# ____________________________________________________________________________________________________
# masking_layer_1 (Masking)        (None, 20, 1)         0           sequence_layer_1[0][0]
# ____________________________________________________________________________________________________
# masking_layer_2 (Masking)        (None, 20, 1)         0           sequence_layer_2[0][0]
# ____________________________________________________________________________________________________
# masking_layer_3 (Masking)        (None, 20, 1)         0           sequence_layer_3[0][0]
# ____________________________________________________________________________________________________
# encoder_lstm_0 (LSTM)            (None, 15)            1020        masking_layer_0[0][0]
# ____________________________________________________________________________________________________
# encoder_lstm_1 (LSTM)            (None, 15)            1020        masking_layer_1[0][0]
# ____________________________________________________________________________________________________
# encoder_lstm_2 (LSTM)            (None, 15)            1020        masking_layer_2[0][0]
# ____________________________________________________________________________________________________
# encoder_lstm_3 (LSTM)            (None, 15)            1020        masking_layer_3[0][0]
# ____________________________________________________________________________________________________
# lstm_sequence_0 (Reshape)        (None, 1, 15)         0           encoder_lstm_0[0][0]
# ____________________________________________________________________________________________________
# lstm_sequence_1 (Reshape)        (None, 1, 15)         0           encoder_lstm_1[0][0]
# ____________________________________________________________________________________________________
# lstm_sequence_2 (Reshape)        (None, 1, 15)         0           encoder_lstm_2[0][0]
# ____________________________________________________________________________________________________
# lstm_sequence_3 (Reshape)        (None, 1, 15)         0           encoder_lstm_3[0][0]
# ____________________________________________________________________________________________________
# core_merge (Merge)               (None, 4, 15)         0           lstm_sequence_0[0][0]
#                                                                    lstm_sequence_1[0][0]
#                                                                    lstm_sequence_2[0][0]
#                                                                    lstm_sequence_3[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 60)            0           core_merge[0][0]
# ____________________________________________________________________________________________________
# repeatvector_1 (RepeatVector)    (None, 5, 60)         0           flatten_1[0][0]
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 20, 15)        0           repeatvector_1[0][0]
# ____________________________________________________________________________________________________
# core_lstm (LSTM)                 (None, 20, 17)        2244        reshape_1[0][0]
# ____________________________________________________________________________________________________
# every_other_4 (Lambda)           (None, 5, 17)         0           core_lstm[0][0]
# ____________________________________________________________________________________________________
# pick_seq_0 (Lambda)              (None, 17)            0           every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
# ____________________________________________________________________________________________________
# pick_seq_1 (Lambda)              (None, 17)            0           every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
# ____________________________________________________________________________________________________
# pick_seq_2 (Lambda)              (None, 17)            0           every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
# ____________________________________________________________________________________________________
# pick_seq_3 (Lambda)              (None, 17)            0           every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
# ____________________________________________________________________________________________________
# pick_seq_4 (Lambda)              (None, 17)            0           every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
#                                                                    every_other_4[0][0]
# ____________________________________________________________________________________________________
# decoder_0 (Dense)                (None, 501)           9018        pick_seq_0[0][0]
#                                                                    pick_seq_1[0][0]
#                                                                    pick_seq_2[0][0]
#                                                                    pick_seq_3[0][0]
#                                                                    pick_seq_4[0][0]
# ____________________________________________________________________________________________________
# decoder_1 (Dense)                (None, 501)           9018        pick_seq_0[1][0]
#                                                                    pick_seq_1[1][0]
#                                                                    pick_seq_2[1][0]
#                                                                    pick_seq_3[1][0]
#                                                                    pick_seq_4[1][0]
# ____________________________________________________________________________________________________
# decoder_2 (Dense)                (None, 501)           9018        pick_seq_0[2][0]
#                                                                    pick_seq_1[2][0]
#                                                                    pick_seq_2[2][0]
#                                                                    pick_seq_3[2][0]
#                                                                    pick_seq_4[2][0]
# ____________________________________________________________________________________________________
# decoder_3 (Dense)                (None, 501)           9018        pick_seq_0[3][0]
#                                                                    pick_seq_1[3][0]
#                                                                    pick_seq_2[3][0]
#                                                                    pick_seq_3[3][0]
#                                                                    pick_seq_4[3][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 501)           0           decoder_0[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 501)           0           decoder_0[1][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 501)           0           decoder_0[2][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 501)           0           decoder_0[3][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 501)           0           decoder_0[4][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 501)           0           decoder_1[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 501)           0           decoder_1[1][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 501)           0           decoder_1[2][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 501)           0           decoder_1[3][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 501)           0           decoder_1[4][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 501)           0           decoder_2[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 501)           0           decoder_2[1][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 501)           0           decoder_2[2][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 501)           0           decoder_2[3][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 501)           0           decoder_2[4][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 501)           0           decoder_3[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 501)           0           decoder_3[1][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 501)           0           decoder_3[2][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 501)           0           decoder_3[3][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 501)           0           decoder_3[4][0]
# ====================================================================================================
# Total params: 42396
# ____________________________________________________________________________________________________

# %%
M.convert_files()
# Out:
# dataset_mu10_214.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_175.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_184.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_199.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_127.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_116.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_173.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_11.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_4.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_69.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_38.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_159.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_165.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_99.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_172.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_163.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_100.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_110.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_152.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_81.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_195.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_75.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_68.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_169.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_117.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_162.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_200.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_82.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_111.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_157.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_61.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_25.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_109.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_44.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_6.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_192.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_15.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_202.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_170.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_36.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_27.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_145.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_35.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_45.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_129.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_151.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_103.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_188.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_26.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_94.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_142.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_42.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_141.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_186.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_89.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_12.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_43.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_125.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_93.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_133.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_51.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_139.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_215.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_90.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_87.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_14.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_67.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_130.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_59.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_132.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_77.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_107.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_131.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_55.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_91.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_17.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_212.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_168.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10_83.csvall_4L_20H_5C_DC500.h5 exists already
# dataset_mu10
csvall_4L_20H_5C_DC500.h5',
#  'dataset_mu10_135.csvall_4L_20H_5C_DC500.h5',
#  'dataset_mu10_28.csvall_4L_20H_5C_DC500.h5']

# %%
data, target, _ = M.read_dataset()
# Out:
# dataset_mu10_*all_4L_20H_5C_DC500.h5
# dataset_mu10_39.csvall_4L_20H_5C_DC500.h5
# [ 0.36890431  0.44021628  0.73148337]
# [500]
# dataset_mu10_168.csvall_4L_20H_5C_DC500.h5
# [ 0.05437666  0.17873903  0.51203836]
# [27]
# dataset_mu10_174.csvall_4L_20H_5C_DC500.h5
# [ 0.07304632  0.1234442   0.21260967]
# [36]
# dataset_mu10_129.csvall_4L_20H_5C_DC500.h5
# [ 0.04570496  0.29524587  0.30708019]
# [22]
# dataset_mu10_17.csvall_4L_20H_5C_DC500.h5
# [ 0.0596817   0.0703938   0.09528668]
# [47]
# dataset_mu10_54.csvall_4L_20H_5C_DC500.h5
# [ 0.0923281   0.29238931  0.39247092]
# [146]
# dataset_mu10_114.csvall_4L_20H_5C_DC500.h5
# [ 0.05641706  0.25045909  0.25117323]
# [125]
# dataset_mu10_78.csvall_4L_20H_5C_DC500.h5
# [ 0.17904509  0.35492757  0.50683534]
# [253]
# dataset_mu10_213.csvall_4L_20H_5C_DC500.h5
# [ 0.01295654  0.39828606  0.59528668]
# [6]
# dataset_mu10_72.csvall_4L_20H_5C_DC500.h5
# [ 0.09345032  0.14354213  0.23342175]
# [46]
# dataset_mu10_47.csvall_4L_20H_5C_DC500.h5
# [ 0.0346868   0.05376454  0.11742502]
# [17]
# dataset_mu10_216.csvall_4L_20H_5C_DC500.h5
# [ 0.13303407  0.26412977  0.27780045]
# [66]
# dataset_mu10_176.csvall_4L_20H_5C_DC500.h5
# [ 0.01367068  0.03234034  0.24933687]
# [6]
# dataset_mu10_86.csvall_4L_20H_5C_DC500.h5
# [ 0.27086309  0.39420526  0.43154458]
# [215]
# dataset_mu10_185.csvall_4L_20H_5C_DC500.h5
# [ 0.07620894  0.0948786   0.21699653]
# [108]
# dataset_mu10_166.csvall_4L_20H_5C_DC500.h5
# [ 0.02111814  0.06559886  0.17006733]
# [10]
# dataset_mu10_175.csvall_4L_20H_5C_DC500.h5
# [ 0.00948786  0.15762089  0.21618037]
# [4]
# dataset_mu10_58.csvall_4L_20H_5C_DC500.h5
# [ 0.01693532  0.02519894  0.19128749]
# [95]
# dataset_mu10_21.csvall_4L_20H_5C_DC500.h5
# [ 0.64333809  0.78483983  0.78871659]
# [321]
# dataset_mu10_155.csvall_4L_20H_5C_DC500.h5
# [ 0.01958784  0.22372985  0.38716588]
# [500]
# dataset_mu10_160.csvall_4L_20H_5C_DC500.h5
# [ 0.22852479  0.27800449  0.30473373]
# [114]
# dataset_mu10_49.csvall_4L_20H_5C_DC500.h5
# [ 0.05396858  0.07008774  0.4041012 ]
# [26]
# dataset_mu10_107.csvall_4L_20H_5C_DC500.h5
# [ 0.11762906  0.17751479  0.20036727]
# [58]
# dataset_mu10_115.csvall_4L_20H_5C_DC500.h5
# [ 0.02254642  0.08600286  0.1086513 ]
# [11]
# dataset_mu10_74.csvall_4L_20H_5C_DC500.h5
# [ 0.06743522  0.15251989  0.36461947]
# [76]
# dataset_mu10_169.csvall_4L_20H_5C_DC500.h5
# [ 0.06825138  0.25545807  0.35472353]
# [34]
# dataset_mu10_197.csvall_4L_20H_5C_DC500.h5
# [ 0.16272189  0.19220567  0.32840237]
# [81]
# dataset_mu10_70.csvall_4L_20H_5C_DC500.h5
# [ 0.12854519  0.24729647  0.35951847]
# [64]
# dataset_mu10_164.csvall_4L_20H_5C_DC500.h5
# [ 0.4290961   0.46245664  0.49418486]
# [231]
# dataset_mu10_60.csvall_4L_20H_5C_DC500.h5
# [ 0.00744746  0.19781677  0.40654968]
# [98]
# dataset_mu10_154.csvall_4L_20H_5C_DC500.h5
# [ 0.07988166  0.10069374  0.19383799]
# [50]
# dataset_mu10_8.csvall_4L_20H_5C_DC500.h5
# [ 0.08804326  0.10569272  0.21291573]
# [52]
# dataset_mu10_159.csvall_4L_20H_5C_DC500.h5
# [ 0.0469292   0.27667823  0.42685166]
# [339]
# ModelAndData.py:295: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if data==None or target == None:
# dataset_mu10_63.csvall_4L_20H_5C_DC500.h5
# [ 0.22719853  0.26117119  0.32972863]
# [113]
# dataset_mu10_202.csvall_4L_20H_5C_DC500.h5
# [ 0.16833299  0.41909814  0.49255254]
# [500]
# dataset_mu10_208.csvall_4L_20H_5C_DC500.h5
# [ 0.23301367  0.29238931  0.4326668 ]
# [116]
# dataset_mu10_104.csvall_4L_20H_5C_DC500.h5
# [ 0.15792695  0.39818404  0.41369108]
# [78]
# dataset_mu10_53.csvall_4L_20H_5C_DC500.h5
# [ 0.0300959   0.23423791  0.24352173]
# [15]
# dataset_mu10_67.csvall_4L_20H_5C_DC500.h5
# [ 0.13915527  0.16731279  0.21322179]
# [106]
# dataset_mu10_48.csvall_4L_20H_5C_DC500.h5
# [ 0.15394817  0.21352785  0.22709651]
# [76]
# dataset_mu10_73.csvall_4L_20H_5C_DC500.h5
# [ 0.00683534  0.17067945  0.17486227]
# [85]
# dataset_mu10_40.csvall_4L_20H_5C_DC500.h5
# [ 0.06978168  0.23158539  0.26361967]
# [34]
# dataset_mu10_136.csvall_4L_20H_5C_DC500.h5
# [ 0.02927974  0.0800857   0.13436033]
# [40]
# dataset_mu10_45.csvall_4L_20H_5C_DC500.h5
# [ 0.00132626  0.27678025  0.29626607]
# [155]
# dataset_mu10_179.csvall_4L_20H_5C_DC500.h5
# [ 0.0499898   0.06355846  0.06672108]
# [24]
# dataset_mu10_207.csvall_4L_20H_5C_DC500.h5
# [ 0.0300959   0.08345236  0.16884309]
# [15]
# dataset_mu10_205.csvall_4L_20H_5C_DC500.h5
# [ 0.08539074  0.11722098  0.16333401]
# [58]
# dataset_mu10_76.csvall_4L_20H_5C_DC500.h5
# [ 0.15517241  0.21954703  0.31667007]
# [109]
# dataset_mu10_15.csvall_4L_20H_5C_DC500.h5
# [ 0.06294634  0.07100592  0.42185268]
# [31]
# dataset_mu10_62.csvall_4L_20H_5C_DC500.h5
# [ 0.12109774  0.12997347  0.29259335]
# [60]
# dataset_mu10_22.csvall_4L_20H_5C_DC500.h5
# [ 0.11436442  0.16466027  0.16537441]
# [57]
# dataset_mu10_132.csvall_4L_20H_5C_DC500.h5
# [ 0.10202     0.13180983  0.22332177]
# [111]
# dataset_mu10_12.csvall_4L_20H_5C_DC500.h5
# [ 0.0433585   0.07824934  0.0795756 ]
# [21]
# dataset_mu10_194.csvall_4L_20H_5C_DC500.h5
# [ 0.10426444  0.24943889  0.28116711]
# [162]
# dataset_mu10_85.csvall_4L_20H_5C_DC500.h5
# [ 0.29361355  0.37257703  0.41144664]
# [186]
# dataset_mu10_124.csvall_4L_20H_5C_DC500.h5
# [ 0.0020404   0.3770659   0.48602326]
# [188]
# dataset_mu10_81.csvall_4L_20H_5C_DC500.h5
# [ 0.13497245  0.22913691  0.40389716]
# [67]
# dataset_mu10_204.csvall_4L_20H_5C_DC500.h5
# [ 0.04550092  0.04856152  0.07947358]
# [145]
# dataset_mu10_144.csvall_4L_20H_5C_DC500.h5
# [ 0.05886554  0.19771475  0.65802897]
# [500]
# dataset_mu10_83.csvall_4L_20H_5C_DC500.h5
# [ 0.0943685   0.14833707  0.30697817]
# [47]
# dataset_mu10_30.csvall_4L_20H_5C_DC500.h5
# [ 0.01367068  0.02458682  0.27800449]
# [6]
# dataset_mu10_148.csvall_4L_20H_5C_DC500.h5
# [ 0.02917772  0.05233626  0.1183432 ]
# [161]
# dataset_mu10_173.csvall_4L_20H_5C_DC500.h5
# [ 0.18832891  0.56825138  0.73413589]
# [500]
# dataset_mu10_117.csvall_4L_20H_5C_DC500.h5
# [ 0.01795552  0.06396654  0.09396042]
# [46]
# dataset_mu10_167.csvall_4L_20H_5C_DC500.h5
# [ 0.0520302   0.12303612  0.16884309]
# [26]
# dataset_mu10_116.csvall_4L_20H_5C_DC500.h5
# [ 0.06264028  0.07059784  0.15853907]
# [31]
# dataset_mu10_181.csvall_4L_20H_5C_DC500.h5
# [ 0.07161804  0.46041624  0.49255254]
# [35]
# dataset_mu10_220.csvall_4L_20H_5C_DC500.h5
# [ 0.17027137  0.19057335  0.20189757]
# [85]
# dataset_mu10_80.csvall_4L_20H_5C_DC500.h5
# [ 0.08947154  0.11038564  0.28269741]
# [55]
# dataset_mu10_91.csvall_4L_20H_5C_DC500.h5
# [ 0.05284636  0.07896348  0.15007141]
# [39]
# dataset_mu10_66.csvall_4L_20H_5C_DC500.h5
# [ 0.18486023  0.45225464  0.45633544]
# [92]
# dataset_mu10_110.csvall_4L_20H_5C_DC500.h5
# [ 0.05682514  0.16802693  0.21077331]
# [28]
# dataset_mu10_103.csvall_4L_20H_5C_DC500.h5
# [ 0.0107121   0.08681902  0.32911651]
# [5]
# dataset_mu10_29.csvall_4L_20H_5C_DC500.h5
# [ 0.05621302  0.08528872  0.08539074]
# [95]
# dataset_mu10_212.csvall_4L_20H_5C_DC500.h5
# [ 0.08916548  0.1147725   0.23872679]
# [44]
# dataset_mu10_50.csvall_4L_20H_5C_DC500.h5
# [ 0.00377474  0.19496021  0.25219343]
# [97]
# dataset_mu10_3.csvall_4L_20H_5C_DC500.h5
# [ 0.13711487  0.17435217  0.20934503]
# [68]
# dataset_mu10_149.csvall_4L_20H_5C_DC500.h5
# [ 0.0805958   0.20352989  0.24892879]
# [40]
# dataset_mu10_177.csvall_4L_20H_5C_DC500.h5
# [ 0.10569272  0.14048153  0.17445419]
# [52]
# dataset_mu10_187.csvall_4L_20H_5C_DC500.h5
# [ 0.13313609  0.15915119  0.26361967]
# [66]
# dataset_mu10_170.csvall_4L_20H_5C_DC500.h5
# [ 0.01968986  0.21862885  0.25525403]
# [109]
# dataset_mu10_98.csvall_4L_20H_5C_DC500.h5
# [ 0.25453989  0.46796572  0.47163844]
# [500]
# dataset_mu10_28.csvall_4L_20H_5C_DC500.h5
# [ 0.00989594  0.55682514  0.61232402]
# [4]
# dataset_mu10_199.csvall_4L_20H_5C_DC500.h5
# [ 0.0270353   0.0270353   0.04356254]
# [21]
# dataset_mu10_133.csvall_4L_20H_5C_DC500.h5
# [ 0.06998572  0.15925321  0.19934707]
# [79]
# dataset_mu10_215.csvall_4L_20H_5C_DC500.h5
# [ 0.0933483   0.14160375  0.32299531]
# [70]
# dataset_mu10_10.csvall_4L_20H_5C_DC500.h5
# [ 0.13385023  0.16425219  0.22597429]
# [66]
# dataset_mu10_31.csvall_4L_20H_5C_DC500.h5
# [ 0.21056927  0.64813303  0.84401143]
# [105]
# dataset_mu10_38.csvall_4L_20H_5C_DC500.h5
# [ 0.08906346  0.1147725   0.15027545]
# [164]
# dataset_mu10_102.csvall_4L_20H_5C_DC500.h5
# [ 0.08049378  0.18741073  0.51805754]
# [93]
# dataset_mu10_191.csvall_4L_20H_5C_DC500.h5
# [ 0.04927566  0.08426852  0.15578453]
# [121]
# dataset_mu10_18.csvall_4L_20H_5C_DC500.h5
# [ 0.30718221  0.34625587  0.37380127]
# [153]
# dataset_mu10_51.csvall_4L_20H_5C_DC500.h5
# [ 0.21189553  0.21475209  0.32319935]
# [339]
# dataset_mu10_68.csvall_4L_20H_5C_DC500.h5
# [ 0.48235054  0.54091002  0.6004897 ]
# [241]
# dataset_mu10_153.csvall_4L_20H_5C_DC500.h5
# [ 0.24964293  0.27473985  0.76514997]
# [124]
# dataset_mu10_44.csvall_4L_20H_5C_DC500.h5
# [ 0.12375026  0.23607427  0.27371965]
# [61]
# dataset_mu10_130.csvall_4L_20H_5C_DC500.h5
# [ 0.0709039   0.11354826  0.20118343]
# [35]
# dataset_mu10_25.csvall_4L_20H_5C_DC500.h5
# [ 0.01826158  0.30503979  0.40450928]
# [202]
# dataset_mu10_88.csvall_4L_20H_5C_DC500.h5
# [ 0.28422771  0.38379922  0.71332381]
# [500]
# dataset_mu10_57.csvall_4L_20H_5C_DC500.h5
# [ 0.02723934  0.1117119   0.1234442 ]
# [61]
# dataset_mu10_162.csvall_4L_20H_5C_DC500.h5
# [ 0.04203224  0.0586615   0.1091614 ]
# [29]
# dataset_mu10_94.csvall_4L_20H_5C_DC500.h5
# [ 0.09396042  0.13272801  0.39920424]
# [46]
# dataset_mu10_151.csvall_4L_20H_5C_DC500.h5
# [ 0.00173434  0.0698837   0.19210365]
# [0]
# dataset_mu10_123.csvall_4L_20H_5C_DC500.h5
# [ 0.43756376  0.47367884  0.49194042]
# [218]
# dataset_mu10_37.csvall_4L_20H_5C_DC500.h5
# [ 0.01499694  0.04366456  0.10222404]
# [21]
# dataset_mu10_147.csvall_4L_20H_5C_DC500.h5
# [ 0.17455621  0.38502346  0.65435625]
# [87]
# dataset_mu10_137.csvall_4L_20H_5C_DC500.h5
# [ 0.12426036  0.14068557  0.18904305]
# [62]
# dataset_mu10_65.csvall_4L_20H_5C_DC500.h5
# [ 0.4535809   0.53203428  0.56294634]
# [226]
# dataset_mu10_211.csvall_4L_20H_5C_DC500.h5
# [ 0.02866762  0.07733116  0.17384207]
# [14]
# dataset_mu10_41.csvall_4L_20H_5C_DC500.h5
# [ 0.27371965  0.30738625  0.55702918]
# [153]
# dataset_mu10_52.csvall_4L_20H_5C_DC500.h5
# [ 0.05294838  0.05896756  0.1208937 ]
# [26]
# dataset_mu10_90.csvall_4L_20H_5C_DC500.h5
# [ 0.04631708  0.18098347  0.25821261]
# [198]
# dataset_mu10_23.csvall_4L_20H_5C_DC500.h5
# [ 0.04325648  0.09355234  0.29789839]
# [46]
# dataset_mu10_111.csvall_4L_20H_5C_DC500.h5
# [ 0.01724138  0.19394001  0.33615589]
# [8]
# dataset_mu10_100.csvall_4L_20H_5C_DC500.h5
# [ 0.0846766   0.27688227  0.30004081]
# [138]
# dataset_mu10_6.csvall_4L_20H_5C_DC500.h5
# [ 0.37941236  0.40063252  0.68241175]
# [341]
# dataset_mu10_89.csvall_4L_20H_5C_DC500.h5
# [ 0.37227097  0.37410733  0.62099572]
# [186]
# dataset_mu10_186.csvall_4L_20H_5C_DC500.h5
# [ 0.03733932  0.12466844  0.42970822]
# [18]
# dataset_mu10_119.csvall_4L_20H_5C_DC500.h5
# [ 0.05141808  0.13895123  0.58039176]
# [25]
# dataset_mu10_178.csvall_4L_20H_5C_DC500.h5
# [ 0.14150173  0.16782289  0.22587227]
# [112]
# dataset_mu10_32.csvall_4L_20H_5C_DC500.h5
# [ 0.0045909   0.01132422  0.09243012]
# [46]
# dataset_mu10_96.csvall_4L_20H_5C_DC500.h5
# [ 0.04223628  0.10324424  0.15833503]
# [51]
# dataset_mu10_209.csvall_4L_20H_5C_DC500.h5
# [ 0.05111202  0.1234442   0.15680473]
# [61]
# dataset_mu10_122.csvall_4L_20H_5C_DC500.h5
# [ 0.04580698  0.076515    0.16802693]
# [84]
# dataset_mu10_20.csvall_4L_20H_5C_DC500.h5
# [ 0.02560702  0.122424    0.16466027]
# [209]
# dataset_mu10_157.csvall_4L_20H_5C_DC500.h5
# [ 0.0015303   0.08896144  0.0948786 ]
# [47]
# dataset_mu10_4.csvall_4L_20H_5C_DC500.h5
# [ 0.00775352  0.24923485  0.36482351]
# [3]
# dataset_mu10_171.csvall_4L_20H_5C_DC500.h5
# [ 0.12568863  0.12854519  0.13415629]
# [67]
# dataset_mu10_196.csvall_4L_20H_5C_DC500.h5
# [ 0.13017751  0.69740869 -1.        ]
# [500]
# dataset_mu10_113.csvall_4L_20H_5C_DC500.h5
# [ 0.05723322  0.13313609  0.26759845]
# [137]
# dataset_mu10_1.csvall_4L_20H_5C_DC500.h5
# [ 0.01030402  0.02672924  0.46949602]
# [234]
# dataset_mu10_69.csvall_4L_20H_5C_DC500.h5
# [ 0.18128953  0.18975719  0.3765558 ]
# [90]
# dataset_mu10_36.csvall_4L_20H_5C_DC500.h5
# [ 0.03642114  0.23005509  0.25096919]
# [18]
# dataset_mu10_201.csvall_4L_20H_5C_DC500.h5
# [ 0.04295042  0.25913079  0.29800041]
# [21]
# dataset_mu10_140.csvall_4L_20H_5C_DC500.h5
# [ 0.01642522  0.05672312  0.07835136]
# [39]
# dataset_mu10_109.csvall_4L_20H_5C_DC500.h5
# [ 0.03580902  0.16119159  0.27647419]
# [80]
# dataset_mu10_118.csvall_4L_20H_5C_DC500.h5
# [  8.16159967e-04   6.45072434e-01   9.17975923e-01]
# [500]
# dataset_mu10_217.csvall_4L_20H_5C_DC500.h5
# [ 0.05264232  0.21332381  0.25964089]
# [26]
# dataset_mu10_219.csvall_4L_20H_5C_DC500.h5
# [ 0.00030606  0.04723526  0.06763926]
# [23]
# dataset_mu10_189.csvall_4L_20H_5C_DC500.h5
# [ 0.11609876  0.32411753  0.33227913]
# [162]
# dataset_mu10_192.csvall_4L_20H_5C_DC500.h5
# [ 0.00683534  0.07304632  0.09018568]
# [36]
# dataset_mu10_143.csvall_4L_20H_5C_DC500.h5
# [ 0.02866762  0.28534993  0.36696593]
# [142]
# dataset_mu10_42.csvall_4L_20H_5C_DC500.h5
# [ 0.07467864  0.09477658  0.13303407]
# [37]
# dataset_mu10_218.csvall_4L_20H_5C_DC500.h5
# [ 0.00285656  0.19159355  0.49765354]
# [1]
# dataset_mu10_182.csvall_4L_20H_5C_DC500.h5
# [ 0.04417466  0.07692308  0.23331973]
# [22]
# dataset_mu10_16.csvall_4L_20H_5C_DC500.h5
# [ 0.05060192  0.14190981  0.19638849]
# [70]
# dataset_mu10_128.csvall_4L_20H_5C_DC500.h5
# [ 0.12221996  0.17863701  0.18271781]
# [61]
# dataset_mu10_127.csvall_4L_20H_5C_DC500.h5
# [ 0.0790655   0.31718017  0.48969598]
# [317]
# dataset_mu10_200.csvall_4L_20H_5C_DC500.h5
# [ 0.04917364  0.34666395  0.40022444]
# [24]
# dataset_mu10_214.csvall_4L_20H_5C_DC500.h5
# [ 0.04305244  0.15445827  0.17690267]
# [195]
# dataset_mu10_99.csvall_4L_20H_5C_DC500.h5
# [ 0.00591716  0.31850643  0.32207713]
# [2]
# dataset_mu10_141.csvall_4L_20H_5C_DC500.h5
# [ 0.14650071  0.16802693  0.19475617]
# [73]
# dataset_mu10_142.csvall_4L_20H_5C_DC500.h5
# [ 0.08896144  0.1035503   0.14078759]
# [164]
# dataset_mu10_71.csvall_4L_20H_5C_DC500.h5
# [ 0.10059172  0.17261783  0.25607019]
# [50]
# dataset_mu10_26.csvall_4L_20H_5C_DC500.h5
# [ 0.01948582  0.03642114  0.17445419]
# [18]
# dataset_mu10_2.csvall_4L_20H_5C_DC500.h5
# [ 0.08834932  0.09620486  0.11752704]
# [58]
# dataset_mu10_33.csvall_4L_20H_5C_DC500.h5
# [ 0.07437258  0.19383799  0.24556213]
# [37]
# dataset_mu10_134.csvall_4L_20H_5C_DC500.h5
# [ 0.00265252  0.14517445  0.49785758]
# [72]
# dataset_mu10_34.csvall_4L_20H_5C_DC500.h5
# [ 0.13272801  0.15241787  0.20434605]
# [66]
# dataset_mu10_87.csvall_4L_20H_5C_DC500.h5
# [ 0.0948786   0.22791267  0.30371353]
# [151]
# dataset_mu10_138.csvall_4L_20H_5C_DC500.h5
# [ 0.0280555   0.15445827  0.4556213 ]
# [14]
# dataset_mu10_64.csvall_4L_20H_5C_DC500.h5
# [ 0.14252193  0.24199143  0.24658233]
# [71]
# dataset_mu10_193.csvall_4L_20H_5C_DC500.h5
# [ 0.19995919  0.20903897  0.53397266]
# [104]
# dataset_mu10_188.csvall_4L_20H_5C_DC500.h5
# [ 0.02234238  0.5107121   0.53917568]
# [11]
# dataset_mu10_158.csvall_4L_20H_5C_DC500.h5
# [ 0.28249337  0.31452765  0.40685574]
# [141]
# dataset_mu10_95.csvall_4L_20H_5C_DC500.h5
# [ 0.18598245  0.59140992  0.59977556]
# [500]
# dataset_mu10_108.csvall_4L_20H_5C_DC500.h5
# [ 0.09365436  0.14854111  0.23974699]
# [46]
# dataset_mu10_43.csvall_4L_20H_5C_DC500.h5
# [ 0.04101204  0.13538053  0.20373393]
# [20]
# dataset_mu10_27.csvall_4L_20H_5C_DC500.h5
# [ 0.00397878  0.02927974  0.18465619]
# [1]
# dataset_mu10_105.csvall_4L_20H_5C_DC500.h5
# [ 0.02632116  0.22719853  0.23117731]
# [113]
# dataset_mu10_161.csvall_4L_20H_5C_DC500.h5
# [ 0.02917772  0.17180167  0.17588247]
# [87]
# dataset_mu10_5.csvall_4L_20H_5C_DC500.h5
# [ 0.06335442  0.14037951  0.17353601]
# [31]
# dataset_mu10_190.csvall_4L_20H_5C_DC500.h5
# [ 0.05437666  0.14058355  0.30524383]
# [70]
# dataset_mu10_145.csvall_4L_20H_5C_DC500.h5
# [ 0.09263416  0.13640073  0.16894511]
# [46]
# dataset_mu10_221.csvall_4L_20H_5C_DC500.h5
# [ 0.02519894  0.30493777  0.4316466 ]
# [12]
# dataset_mu10_24.csvall_4L_20H_5C_DC500.h5
# [ 0.10783514  0.17741277  0.18894103]
# [88]
# dataset_mu10_150.csvall_4L_20H_5C_DC500.h5
# [ 0.04733728  0.47112834  0.78422771]
# [23]
# dataset_mu10_146.csvall_4L_20H_5C_DC500.h5
# [ 0.13476841  0.15772291  0.31034483]
# [67]
# dataset_mu10_79.csvall_4L_20H_5C_DC500.h5
# [ 0.09814324  0.34972455  0.459192  ]
# [49]
# dataset_mu10_152.csvall_4L_20H_5C_DC500.h5
# [ 0.21403795  0.30208121  0.35482555]
# [151]
# dataset_mu10_84.csvall_4L_20H_5C_DC500.h5
# [ 0.35645787  0.38890022  0.39614364]
# [178]
# dataset_mu10_93.csvall_4L_20H_5C_DC500.h5
# [ 0.16415017  0.17465823  0.32513773]
# [87]
# dataset_mu10_156.csvall_4L_20H_5C_DC500.h5
# [ 0.0601918   0.11609876  0.19710263]
# [58]
# dataset_mu10_210.csvall_4L_20H_5C_DC500.h5
# [ 0.06029382  0.10803918  0.32289329]
# [161]
# dataset_mu10_183.csvall_4L_20H_5C_DC500.h5
# [ 0.03999184  0.06570088  0.15251989]
# [76]
# dataset_mu10_97.csvall_4L_20H_5C_DC500.h5
# [ 0.0173434   0.19475617  0.27688227]
# [97]
# dataset_mu10_11.csvall_4L_20H_5C_DC500.h5
# [ 0.00785554  0.10701898  0.46194654]
# [53]
# dataset_mu10_19.csvall_4L_20H_5C_DC500.h5
# [ 0.12640277  0.21495613  0.49479698]
# [63]
# dataset_mu10_163.csvall_4L_20H_5C_DC500.h5
# [ 0.29300143  0.65190777 -1.        ]
# [500]
# dataset_mu10_92.csvall_4L_20H_5C_DC500.h5
# [ 0.05060192  0.22301571  0.23270761]
# [116]
# dataset_mu10_61.csvall_4L_20H_5C_DC500.h5
# [ 0.0479494   0.07875944  0.10589676]
# [23]
# dataset_mu10_35.csvall_4L_20H_5C_DC500.h5
# [ 0.00775352  0.02356662  0.03703326]
# [85]
# dataset_mu10_75.csvall_4L_20H_5C_DC500.h5
# [ 0.28259539  0.47775964  0.58335034]
# [238]
# dataset_mu10_180.csvall_4L_20H_5C_DC500.h5
# [ 0.14925525  0.16170169  0.33329933]
# [74]
# dataset_mu10_7.csvall_4L_20H_5C_DC500.h5
# [ 0.0040808   0.0331565   0.07559682]
# [2]
# dataset_mu10_9.csvall_4L_20H_5C_DC500.h5
# [ 0.08936952  0.11334422  0.63793103]
# [44]
# dataset_mu10_82.csvall_4L_20H_5C_DC500.h5
# [ 0.09855132  0.19006325  0.25219343]
# [500]
# dataset_mu10_135.csvall_4L_20H_5C_DC500.h5
# [ 0.00999796  0.41603754  0.57773924]
# [4]
# dataset_mu10_195.csvall_4L_20H_5C_DC500.h5
# [ 0.06437462  0.07865742  0.13599265]
# [67]
# dataset_mu10_56.csvall_4L_20H_5C_DC500.h5
# [ 0.0637625   0.32472965  0.40379514]
# [201]
# dataset_mu10_46.csvall_4L_20H_5C_DC500.h5
# [ 0.00173434  0.08957356  0.21067129]
# [44]
# dataset_mu10_198.csvall_4L_20H_5C_DC500.h5
# [ 0.27718833  0.36053867  0.48153438]
# [180]
# dataset_mu10_55.csvall_4L_20H_5C_DC500.h5
# [ 0.27433177  0.43185064  0.4449092 ]
# [137]
# dataset_mu10_125.csvall_4L_20H_5C_DC500.h5
# [ 0.0112222   0.12813711  0.33605387]
# [209]
# dataset_mu10_172.csvall_4L_20H_5C_DC500.h5
# [ 0.08906346  0.12956539  0.19730667]
# [44]
# dataset_mu10_222.csvall_4L_20H_5C_DC500.h5
# [ 0.20210161  0.34727607  0.42134258]
# [101]
# dataset_mu10_131.csvall_4L_20H_5C_DC500.h5
# [ 0.12262804  0.41348704  0.54601102]
# [61]
# dataset_mu10_106.csvall_4L_20H_5C_DC500.h5
# [ 0.0127525   0.18261579  0.26851663]
# [6]
# dataset_mu10_59.csvall_4L_20H_5C_DC500.h5
# [ 0.03397266  0.05978372  0.13905325]
# [16]
# dataset_mu10_120.csvall_4L_20H_5C_DC500.h5
# [ 0.07784126  0.17231177  0.21964905]
# [38]
# dataset_mu10_112.csvall_4L_20H_5C_DC500.h5
# [ 0.15435625  0.27718833  0.30524383]
# [152]
# dataset_mu10_77.csvall_4L_20H_5C_DC500.h5
# [ 0.19271577  0.31218119  0.34839829]
# [96]
# dataset_mu10_101.csvall_4L_20H_5C_DC500.h5
# [ 0.00285656  0.01295654  0.25443787]
# [6]
# dataset_mu10_13.csvall_4L_20H_5C_DC500.h5
# [ 0.03427872  0.07376046  0.21893491]
# [17]
# dataset_mu10_14.csvall_4L_20H_5C_DC500.h5
# [ 0.27208733  0.29238931  0.42215874]
# [136]
# dataset_mu10_223.csvall_4L_20H_5C_DC500.h5
# [ 0.0010202   0.0683534   0.26504795]
# [0]
# dataset_mu10_184.csvall_4L_20H_5C_DC500.h5
# [ 0.09396042  0.10742706  0.12048562]
# [46]
# dataset_mu10_165.csvall_4L_20H_5C_DC500.h5
# [ 0.18475821  0.20475413  0.26657825]
# [92]
# dataset_mu10_203.csvall_4L_20H_5C_DC500.h5
# [ 0.01928178  0.10242808  0.46612936]
# [51]
# dataset_mu10_126.csvall_4L_20H_5C_DC500.h5
# [ 0.16833299  0.21220159  0.29983677]
# [84]
# dataset_mu10_139.csvall_4L_20H_5C_DC500.h5
# [ 0.10242808  0.10620282  0.12507651]
# [51]
# dataset_mu10_206.csvall_4L_20H_5C_DC500.h5
# [ 0.0336666   0.14252193  0.27229137]
# [16]
# dataset_mu10_121.csvall_4L_20H_5C_DC500.h5
# [ 0.04203224  0.99316466 -1.        ]
# [500]

# %%
M.pick_and_train(data, target)
# Out:
# Starting training round 0 Fri Apr 14 05:10:09 2017
# Trained in 29.0 [s]
# 'model_all_4L_20H_5C_DC500_0_w.h5'

# %%
M.loop_train(data, target)
# Out:
# Starting training round 0 Wed May  3 03:44:43 2017
# Trained in 4563.0 [s]
# 222990/222990 [==============================] - 19s
# round 0 / 10 [98.89034672365942, 4.5339577275117131, 5.1558382228124442, 5.2953404895692318, 5.2552412074266233, 4.6566935356670793, 4.599338367223857, 5.1216682122477426, 5.2495151917556671, 5.2052389374815986, 4.5521091640548876, 4.5890314083868322, 5.0749795303317358, 5.2085001741194867, 5.1771076384496943, 4.5884968892860494, 4.5815718982608775, 5.0767909374422668, 5.2069292232708957, 5.1702172893585923, 4.5917803778328263, 0.085474685260151381, 0.036167541237727502, 0.029723306091564872, 0.027893627692593514, 0.044768823846413515, 0.079734517553658901, 0.052047177105761143, 0.045939279756355866, 0.043535584623221352, 0.057159514087436712, 0.086658594455840454, 0.064007354694338381, 0.057576572891976131, 0.055249114354831062, 0.058675277099608736, 0.091013049987729522, 0.068935827002489944, 0.062581281973201661, 0.060025113303274619, 0.061226961090696343]
# 	model_all_4L_20H_5C_DC500_0_w.h5 found. skipping step
# model_all_4L_20H_5C_DC500