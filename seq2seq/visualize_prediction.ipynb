# %%
from ModelAndData import ModelDealer
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
M = ModelDealer( downcast = 500, base = 'dataset_mu10_')
# Out:
# Ready for model all_4L_20H_5C_DC500

# %%
M.make_model()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# phi_layers (InputLayer)          (None, 4, 20)         0
# ____________________________________________________________________________________________________
# split_0 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ____________________________________________________________________________________________________
# split_1 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ____________________________________________________________________________________________________
# split_2 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ____________________________________________________________________________________________________
# split_3 (Lambda)                 (None, 20)            0           phi_layers[0][0]
# ...

# %%
weights = M.best_model()
# Out:
# 	model_all_4L_20H_5C_DC500_0_w.h5 found. skipping step
# 	model_all_4L_20H_5C_DC500_1_w.h5 found. skipping step
# 	model_all_4L_20H_5C_DC500_2_w.h5 found. skipping step
# model_all_4L_20H_5C_DC500_2_w.h5 found. Using it

# %%
data, target, truth = M.read_dataset(M.list_dataset()[10], andtruth=True)
# Out:
# dataset_mu10_108.csvall_4L_20H_5C_DC500.h5
# dataset_mu10_108.csvall_4L_20H_5C_DC500.h5
# [ 0.09365436  0.14854111  0.23974699]
# [46]

# %%
prediction = M.model.predict(data)

# %% [markdown]
# # show an event

# %%
M.visualize( 10, data, target, prediction, truth, showTruth=False )

# %% [markdown]
# # show a series of events

# %%
import random
select = range(data.shape[0])
random.shuffle( select )

# %%
for i in select[:10]:
    M.visualize( i, data, target, prediction, truth, showTruth=False )

# %% [markdown]
# # show the evolution of an event accross training

# %%
showEvent = 13
for w in weights:
    M.model.load_weights( w )
    sub_pred = M.model.predict( data )
    M.visualize( showEvent, data, target, sub_pred, truth,
                showTruth=False,
                extraTitle=w)
